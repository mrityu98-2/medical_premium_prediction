# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.stats as stats
import pickle

# %%
df=pd.read_csv('./MedicalPremium.csv')
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
df.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
# Finds correlation between Independent and dependent attributes
df_numeric = df.select_dtypes(include=['int64'])
plt.figure(figsize = (15,15))
sb.heatmap(df_numeric.corr(), annot = True, cmap = "coolwarm")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot the distribution plot (displot)
sb.histplot(df, x='Age',kde=True, ax=axes[0])
axes[0].set_title('Distribution of Age')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')

# Plot the Q-Q plot
stats.probplot(df['Age'],dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot of Age')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['PremiumPrice'], color='orange', alpha=0.5)
plt.title('Scatter Plot of Age vs. Price')
plt.xlabel('Age')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
sb.boxplot(df,x='Age')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <AxesSubplot: xlabel='Age'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# Plot the distribution plot (displot)
sb.histplot(df, x='PremiumPrice',kde=True, ax=axes[0])
axes[0].set_title('Distribution of Price')
axes[0].set_xlabel('PremiumPrice')
axes[0].set_ylabel('Frequency')
# Plot the Q-Q plot
stats.probplot(df['PremiumPrice'],dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot of PremiumPrice')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
df['AnyTransplants'].value_counts()
# Out:
# AnyTransplants
# 0    931
# 1     55
# Name: count, dtype: int64

# %%
sb.countplot(df,x='AnyTransplants')
# Out:
# <AxesSubplot: xlabel='AnyTransplants', ylabel='count'>

# %%
sb.displot(df,x='PremiumPrice',hue='AnyTransplants',kind='kde')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sb.countplot(df,x='NumberOfMajorSurgeries')
# Out:
# <AxesSubplot: xlabel='NumberOfMajorSurgeries', ylabel='count'>

# %%
sb.displot(df,x='PremiumPrice',hue='NumberOfMajorSurgeries',kind='kde')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_4704\1088632151.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sb.displot(df,x='PremiumPrice',hue='NumberOfMajorSurgeries',kind='kde')
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sb.countplot(df,x='AnyChronicDiseases')
# Out:
# <AxesSubplot: xlabel='AnyChronicDiseases', ylabel='count'>

# %%
sb.displot(df,x='PremiumPrice',hue='AnyChronicDiseases',kind='kde')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# Plot the distribution plot (displot)
sb.histplot(df, x='Height',kde=True, ax=axes[0])
axes[0].set_title('Distribution of Height')
axes[0].set_xlabel('Height')
axes[0].set_ylabel('Frequency')
# Plot the Q-Q plot
stats.probplot(df['Height'],dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot of Height')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
# Plot the distribution plot (displot)
sb.histplot(df, x='Weight',kde=True, ax=axes[0])
axes[0].set_title('Distribution of Weight')
axes[0].set_xlabel('Weight')
axes[0].set_ylabel('Frequency')
# Plot the Q-Q plot
stats.probplot(df['Weight'],dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot of Weight')
# Adjust layout
plt.tight_layout()
plt.show()

# %%
bin_labels = ['Low', 'Moderate Low', 'Moderate', 'Moderate High', 'High']
df['PremiumLabel']=pd.cut(df['PremiumPrice'],bins=5,labels=bin_labels,precision=0)
df['AgeLabel']=pd.cut(df['Age'],bins=5,labels=bin_labels,precision=0)
df['WeightLabel']=pd.cut(df['Weight'],bins=5,labels=bin_labels,precision=0)
df['HeightLabel']=pd.cut(df['Height'],bins=5,labels=bin_labels,precision=0)

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice',
#        'PremiumLabel', 'AgeLabel', 'WeightLabel', 'HeightLabel'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 934   54         1                      1               0                   0
# 511   35         1                      1               0                   0
# 677   61         0                      0               0                   0
# 594   44         0                      1               0                   1
# 74    53         1                      0               0                   0
# 643   51         0                      1               0                   0
# 883   22         0                      1               0                   0
# 233   29         1                      1               0                   1
# 299   35         0                      1               0                   0
# 135   27         1                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# ...

# %%
sb.countplot(df,x='PremiumLabel',hue='AgeLabel')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sb.countplot(df,x='PremiumLabel',hue='AnyTransplants')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <AxesSubplot: xlabel='PremiumLabel', ylabel='count'>

# %%
sb.countplot(df,x='PremiumLabel',hue='NumberOfMajorSurgeries')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sb.countplot(data=df,x='PremiumLabel',hue='WeightLabel')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sb.countplot(data=df,x='PremiumLabel',hue='AnyChronicDiseases')
# Out:
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\mrmkc\AppData\Roaming\Python\Python311\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <AxesSubplot: xlabel='PremiumLabel', ylabel='count'>

# %%
df.groupby(['AgeLabel'])['PremiumPrice'].mean().plot(kind='bar')
# Out:
# C:\Users\mrmkc\AppData\Local\Temp\ipykernel_4704\2833468510.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['AgeLabel'])['PremiumPrice'].mean().plot(kind='bar')
# <AxesSubplot: xlabel='AgeLabel'>

# %%
df_ohe=pd.get_dummies(data=df,columns=['PremiumLabel','AgeLabel','WeightLabel','HeightLabel'],drop_first=True)
df_ohe.sample(4)
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 772   41         1                      0               0                   0
# 720   51         1                      1               0                   0
# 577   43         1                      1               0                   0
# 15    38         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 772     156      58               0                        0
# 720     163      73               0                        0
# 577     166      79               0                        0
# 15      160      68               1                        0
#
#      NumberOfMajorSurgeries  ...  AgeLabel_Moderate High  AgeLabel_High  \
# 772                       0  ...                   False          False
# 720                       0  ...                    True          False
# ...

# %%
y=df_ohe['PremiumPrice']
x=df_ohe.drop(columns=['PremiumPrice'],axis=1)
x.shape
# Out:
# (986, 26)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=33,test_size=0.3)

# %%
from sklearn.feature_selection import mutual_info_regression
mi_scores = mutual_info_regression(x_train,y_train)
mi_scores = pd.Series(mi_scores, name="MI Scores",index=x.columns)
mi_scores = mi_scores.sort_values(ascending=False)
(mi_scores*100).head(15).index
# Out:
# Index(['Age', 'PremiumLabel_Moderate Low', 'PremiumLabel_Moderate',
#        'NumberOfMajorSurgeries', 'PremiumLabel_Moderate High', 'Weight',
#        'AgeLabel_High', 'AgeLabel_Moderate', 'PremiumLabel_High',
#        'AgeLabel_Moderate Low', 'AnyChronicDiseases', 'AnyTransplants',
#        'AgeLabel_Moderate High', 'HistoryOfCancerInFamily',
#        'WeightLabel_Moderate Low'],
#       dtype='object')

# %%
feature_list=list((mi_scores*100).head(15).index)
x_train=x_train[feature_list]
x_test=x_test[feature_list]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)

# %%
x_train_scaled.shape
# Out:
# (690, 15)

# %%
x_test_scaled=pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
x_test_scaled.shape
# Out:
# (296, 15)

# %%
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
rf_reg=RandomForestRegressor(n_estimators=20,random_state=42)
rf_reg.fit(x_train_scaled,y_train)
# Out:
# RandomForestRegressor(n_estimators=20, random_state=42)

# %%
rf_reg_pred=rf_reg.predict(x_test_scaled)
rf_reg_accuracy=r2_score(y_test,rf_reg_pred)
print(f'Accuarcy is sort of {rf_reg_accuracy*100:.2f}%')
# Out:
# Accuarcy is sort of 98.77%

# %%
rf_reg_mse = mean_squared_error(y_test,rf_reg_pred)
print(f'Mean Squared Error: {rf_reg_mse:.2f}')
# Out:
# Mean Squared Error: 474788.85

# %%
rf_reg_mae = mean_absolute_error(y_test,rf_reg_pred)
print(f'Mean Absolute Error: {rf_reg_mae:.2f}')
# Out:
# Mean Absolute Error: 164.36

# %%
pickle.dump(rf_reg, open('rf_reg_insurance.pkl', 'wb'))

# %%
plt.figure(figsize = (8,8))
sb.displot(y_test-rf_reg_pred,kde=True)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.scatter(y_test,rf_reg_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
param_grid = {
    'n_estimators': [10,20,25,30,40,50,60,65,85,100,120],
    'max_features': ['sqrt','log2',1.0],
    'max_depth': [6,7,9,11,12],
    'criterion':['squared_error','absolute_error']
}

# %%
rf_reg_hyp=GridSearchCV(RandomForestRegressor(random_state=42),param_grid=param_grid,cv=5,n_jobs=-1,verbose=1,scoring='neg_mean_squared_error')
rf_reg_hyp.fit(x_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 330 candidates, totalling 1650 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [6, 7, 9, 11, 12],
#                          'max_features': ['sqrt', 'log2', 1.0],
#                          'n_estimators': [10, 20, 25, 30, 40, 50, 60, 65, 85,
#                                           100, 120]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
best_params = rf_reg_hyp.best_params_
print(f'Best parameters: {best_params}')
# Out:
# Best parameters: {'criterion': 'squared_error', 'max_depth': 11, 'max_features': 'sqrt', 'n_estimators': 30}

# %%
rf_reg_clf = rf_reg_hyp.best_estimator_
rf_reg_hyp_pred = rf_reg_clf.predict(x_test_scaled)

# %%
rf_reg_hyp_accuracy=r2_score(y_test,rf_reg_hyp_pred)
print(f'Accuarcy is sort of {rf_reg_hyp_accuracy*100:.2f}%')
# Out:
# Accuarcy is sort of 97.78%

# %%
rf_reg_hyp_mse = mean_squared_error(y_test,rf_reg_hyp_pred)
print(f'Mean Squared Error: {rf_reg_hyp_mse:.2f}')
rf_reg_hyp_mae = mean_absolute_error(y_test,rf_reg_hyp_pred)
print(f'Mean Absolute Error: {rf_reg_hyp_mae:.2f}')
# Out:
# Mean Squared Error: 855728.84
# Mean Absolute Error: 398.22

# %%
gb_reg = GradientBoostingRegressor(random_state=42)
gb_reg.fit(x_train_scaled,y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
gb_reg_pred=gb_reg.predict(x_test_scaled)

# %%
gb_reg_accuracy=r2_score(y_test,gb_reg_pred)
print(f'Accuarcy is sort of {gb_reg_accuracy*100:.2f}%')
gb_reg_mse = mean_squared_error(y_test,gb_reg_pred)
print(f'Mean Squared Error: {gb_reg_mse:.2f}')
gb_reg_mae = mean_absolute_error(y_test,gb_reg_pred)
print(f'Mean Absolute Error: {gb_reg_mae:.2f}')
# Out:
# Accuarcy is sort of 95.41%
# Mean Squared Error: 1763828.34
# Mean Absolute Error: 441.11

# %%
param_grid = {
    'n_estimators': [10,20,25,30,40,50,60,65,85,100,120],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5,7,9,11,13],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
gb_reg_hyp=GridSearchCV(GradientBoostingRegressor(random_state=42),param_grid=param_grid,cv=5,n_jobs=-1,verbose=1,scoring='neg_mean_squared_error')
gb_reg_hyp.fit(x_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 2079 candidates, totalling 10395 fits
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5, 7, 9, 11, 13],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 20, 25, 30, 40, 50, 60, 65, 85,
#                                           100, 120]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
best_params = gb_reg_hyp.best_params_
print(f'Best parameters: {best_params}')
gb_reg_clf = gb_reg_hyp.best_estimator_
gb_reg_hyp_pred = gb_reg_clf.predict(x_test_scaled)
# Out:
# Best parameters: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}

# %%
gb_reg_hyp_accuracy=r2_score(y_test,gb_reg_hyp_pred)
print(f'Accuarcy is sort of {gb_reg_hyp_accuracy*100:.2f}%')
gb_reg_hyp_mse = mean_squared_error(y_test,gb_reg_hyp_pred)
print(f'Mean Squared Error: {gb_reg_hyp_mse:.2f}')
gb_reg_hyp_mae = mean_absolute_error(y_test,gb_reg_hyp_pred)
print(f'Mean Absolute Error: {gb_reg_hyp_mae:.2f}')
# Out:
# Accuarcy is sort of 99.32%
# Mean Squared Error: 262464.28
# Mean Absolute Error: 148.51

# %%
pickle.dump(gb_reg_clf,open('gb_reg_insurance.pkl', 'wb'))

# %%
plt.figure(figsize = (8,8))
sb.displot(y_test-gb_reg_hyp_pred,kde=True)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.scatter(y_test,gb_reg_hyp_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from xgboost import XGBRegressor
xgb_reg = XGBRegressor(random_state=42)

# %%
xgb_reg.fit(x_train_scaled,y_train)
xgb_reg_pred=xgb_reg.predict(x_test_scaled)

# %%
xgb_reg_accuracy=r2_score(y_test,xgb_reg_pred)
print(f'Accuarcy is sort of {xgb_reg_accuracy*100:.2f}%')
xgb_reg_mse = mean_squared_error(y_test,xgb_reg_pred)
print(f'Mean Squared Error: {xgb_reg_mse:.2f}')
xgb_reg_mae = mean_absolute_error(y_test,xgb_reg_pred)
print(f'Mean Absolute Error: {gb_reg_mae:.2f}')
# Out:
# Accuarcy is sort of 99.24%
# Mean Squared Error: 292859.66
# Mean Absolute Error: 441.11

# %%
pickle.dump(xgb_reg,open('xgb_reg_insurance.pkl', 'wb'))

# %%
plt.figure(figsize = (8,8))
sb.displot(y_test-xgb_reg_pred,kde=True)
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.scatter(y_test,xgb_reg_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
param_grid = {
    'n_estimators': [10,20,25,30,40,50,60,65,85,100,120],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5,7,9,11,13],
    'subsample': [0.2,0.4,0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.2,0.4,0.5,0.7, 0.8, 0.9, 1.0]
}

# %%
xgb_reg_hyp= GridSearchCV(estimator=XGBRegressor(random_state=42), param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
xgb_reg_hyp.fit(x_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=42, ...),
#              n_jobs=-1,
# ...

# %%
best_params = xgb_reg_hyp.best_params_
print(f'Best parameters: {best_params}')
xgb_reg_clf = xgb_reg_hyp.best_estimator_ 
xgb_reg_hyp_pred = xgb_reg_clf.predict(x_test_scaled)
# Out:
# Best parameters: {'colsample_bytree': 0.5, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 120, 'subsample': 1.0}

# %%
xgb_reg_hyp_accuracy=r2_score(y_test,xgb_reg_hyp_pred)
print(f'Accuarcy is sort of {xgb_reg_hyp_accuracy*100:.2f}%')
xgb_reg_hyp_mse = mean_squared_error(y_test,xgb_reg_hyp_pred)
print(f'Mean Squared Error: {xgb_reg_hyp_mse:.2f}')
xgb_reg_hyp_mae = mean_absolute_error(y_test,xgb_reg_hyp_pred)
print(f'Mean Absolute Error: {xgb_reg_hyp_mae:.2f}')
# Out:
# Accuarcy is sort of 98.92%
# Mean Squared Error: 416634.69
# Mean Absolute Error: 313.73

# %%
rf_reg_accuracy=round(rf_reg_accuracy,2)
gb_reg_hyp_accuracy=round(gb_reg_hyp_accuracy,2)
xgb_reg_accuracy=round(xgb_reg_accuracy,2)

# %%
data=[
    ['RF',rf_reg_accuracy,rf_reg_mse,rf_reg_mae],
    ['GB',gb_reg_hyp_accuracy,gb_reg_hyp_mse,gb_reg_hyp_mae],
    ['XGB',xgb_reg_accuracy,xgb_reg_mse,xgb_reg_mae]
]

# %%
cols=['Model','R2_Score','MSE','MAE']

# %%
plot_df=pd.DataFrame(data,columns=cols)

# %%
sb.barplot(plot_df,x='R2_Score',y='Model')
# Out:
# <AxesSubplot: xlabel='R2_Score', ylabel='Model'>
